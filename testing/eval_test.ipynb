# %%
# This test is to be run in Google Colab using a GPU backend (tested on A100 runtime)

# %%
# Clone necessary repos
# !git clone --recursive https://github.com/Kacper-M-Michalik/splatter-image.git
# !git clone --recursive https://github.com/graphdeco-inria/gaussian-splatting.git
# Out:
# Cloning into 'splatter-image'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 358 (delta 130), reused 101 (delta 96), pack-reused 185 (from 2)
# Receiving objects: 100% (358/358), 3.01 MiB | 51.35 MiB/s, done.
# Resolving deltas: 100% (199/199), done.
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 1053, done.
# remote: Total 1053 (delta 0), reused 0 (delta 0), pack-reused 1053 (from 1)
# Receiving objects: 100% (1053/1053), 78.70 MiB | 14.65 MiB/s, done.
# Resolving deltas: 100% (604/604), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization.git) registered for path 'submodules/diff-gaussian-rasterization'
# ...

# %%
# Install model requirements
# %cd /content/splatter-image
# !pip install -r requirements.txt
# Out:
# /content/splatter-image
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# Get correct package versions
# %cd /content/gaussian-splatting

import os
from pathlib import Path

os.environ['TORCH_CUDA_ARCH_LIST'] = "7.0;7.5;8.0+PTX"
# !pip install -e submodules/diff-gaussian-rasterization

# %cd /content/
# Out:
# /content/gaussian-splatting
# Obtaining file:///content/gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for diff_gaussian_rasterization
# ...

# %%
scores_path = Path("/content/scores.txt")

# %%
# Test if new Dataset and evaluation script both work
# !python /content/splatter-image/eval.py cars_priors
# Out:
# Evaluating on dataset cars_priors
# Will load a model released with the paper.
# Not saving any renders (only computing scores). To save renders use flag --save_vis
# config.yaml: 1.22kB [00:00, 2.81MB/s]
# model-depth-normal/model_best.pth: 100% 677M/677M [00:04<00:00, 165MB/s]
# Loaded model!
# Started downloading datasets
# README.md: 100% 963/963 [00:00<00:00, 8.23MB/s]
# intrins/train/intrins.parquet: 100% 77.8k/77.8k [00:00<00:00, 99.8kB/s]
# intrins/test/intrins.parquet: 100% 24.4k/24.4k [00:00<00:00, 42.9kB/s]
# intrins/val/intrins.parquet: 100% 13.8k/13.8k [00:00<00:00, 28.6kB/s]
# Generating train split: 100% 2458/2458 [00:00<00:00, 79848.19 examples/s]
# Generating test split: 100% 704/704 [00:00<00:00, 270105.20 examples/s]
# Generating val split: 100% 352/352 [00:00<00:00, 172879.98 examples/s]
# poses/train/poses.parquet: 100% 23.6M/23.6M [00:01<00:00, 13.8MB/s]
# poses/test/poses.parquet: 100% 99.7k/99.7k [00:00<00:00, 200kB/s]
# ...

# %%
# Verify evaluation ended succesfully with scores saved to disk
assert scores_path.exists(), "Model failed to run or output scores!"
print ("cars_priors Eval test successful!")

# Delete scores to test next eval
scores_path.unlink()
# Out:
# cars_priors Eval test successful!

# %%
# Get SRN cars dataset for cars test
# %cd /content
# !mkdir SRN
# %cd /content/SRN
# !mkdir srn_cars
# %cd /content/SRN/srn_cars
# !gdown --id 19yDsEJjx9zNpOKz9o6AaK-E8ED6taJWU -O cars.zip
# !unzip cars.zip
# %cd /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000032.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000015.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000092.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000121.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000192.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000200.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000074.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000142.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000166.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000018.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000077.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000033.txt
#   inflating: cars_val/87ee241d3d0d1dda4ff3c6764341833/pose/000224.txt
# ...

# %%
# Check if previous Datasets and evaluation still work
# !python /content/splatter-image/eval.py cars
# Out:
# Evaluating on dataset cars
# Will load a model released with the paper.
# Not saving any renders (only computing scores). To save renders use flag --save_vis
# Loaded model!
# 704
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# ...

# %%
assert scores_path.exists(), "Model failed to run or output scores!"
print ("cars Eval test successful!")

scores_path.unlink()
# Out:
# cars Eval test successful!
